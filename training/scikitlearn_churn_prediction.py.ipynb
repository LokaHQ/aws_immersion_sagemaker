# %%
import sklearn
from sklearn.ensemble import RandomForestClassifier
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import OneHotEncoder
from sklearn.base import BaseEstimator
import pandas as pd
import numpy as np
import joblib
import boto3

# %% [markdown]
# This is your AWS profile name set locally:

# %%
profile_name = "mfa"

# %%
boto_session = boto3.session.Session(profile_name=profile_name)

# %%
churn = pd.read_csv("./churn.txt")
pd.set_option("display.max_columns", 500)
churn
# Out:
#      State  Account Length  Area Code     Phone Int'l Plan VMail Plan  \
# 0       PA             163        806  403-2562         no        yes
# 1       SC              15        836  158-8416        yes         no
# 2       MO             131        777  896-6253         no        yes
# 3       WY              75        878  817-5729        yes        yes
# 4       WY             146        878  450-4942        yes         no
# ...    ...             ...        ...       ...        ...        ...
# 4995    NH               4        787  151-3162        yes        yes
# 4996    SD             140        836  351-5993         no         no
# 4997    SC              32        836  370-3127         no        yes
# 4998    MA             142        776  604-2108        yes        yes
# 4999    AL             141        657  294-2849        yes        yes
#
#       VMail Message   Day Mins  Day Calls  Day Charge  Eve Mins  Eve Calls  \
# 0               300   8.162204          3    7.579174  3.933035          4
# 1                 0  10.018993          4    4.226289  2.325005          0
# 2               300   4.708490          3    4.768160  4.537466          3
# 3               700   1.268734          3    2.567642  2.528748          5
# 4                 0   2.696177          3    5.908916  6.015337          3
# ...             ...        ...        ...         ...       ...        ...
# 4995            800  10.862632          5    7.250969  6.936164          1
# 4996              0   1.581127          8    3.758307  7.377591          7
# 4997            700   0.163836          5    4.243980  5.841852          3
# 4998            600   2.034454          5    3.014859  4.140554          3
# 4999            500   1.803907          0    5.125716  8.357508          0
#
#       Eve Charge  Night Mins  Night Calls  Night Charge  Intl Mins  \
# 0       6.508639    4.065759          100      5.111624   4.928160
# 1       9.972592    7.141040          200      6.436188   3.221748
# 2       4.566715    5.363235          100      5.142451   7.139023
# 3       2.333624    3.773586          450      3.814413   2.245779
# 4       3.670408    3.751673          250      2.796812   6.905545
# ...          ...         ...          ...           ...        ...
# 4995    8.026482    4.921314          350      6.748489   4.872570
# 4996    1.328827    0.939932          300      4.522661   6.938571
# 4997    2.340554    0.939469          450      5.157898   4.388328
# 4998    3.470372    6.076043          150      4.362780   7.173376
# 4999    2.109823    2.624299          400      3.713631   5.798783
#
#       Intl Calls  Intl Charge  CustServ Calls  Churn?
# 0              6     5.673203               3   True.
# 1              6     2.559749               8  False.
# 2              2     6.254157               4  False.
# 3              6     1.080692               6  False.
# 4              4     7.134343               6   True.
# ...          ...          ...             ...     ...
# 4995           8     2.122530               9  False.
# 4996           2     4.600473               4  False.
# 4997           7     1.060340               6  False.
# 4998           3     4.871900               7   True.
# 4999           6     5.485345               7  False.
#
# [5000 rows x 21 columns]

# %%
churn["Area Code"].unique()
# Out:
# array([806, 836, 777, 878, 866, 737, 766, 657, 676, 827, 716, 786, 778,
#        788, 787, 736, 686, 876, 858, 877, 776, 797, 707, 677, 727, 758,
#        659, 678, 848, 658, 798, 847, 868])

# %%
churn = churn.drop("Phone", axis=1)
churn["Area Code"] = churn["Area Code"].astype(object)

# %%
churn = churn.drop(["Day Charge", "Eve Charge", "Night Charge", "Intl Charge"], axis=1)
model_data = pd.get_dummies(churn)
model_data = pd.concat(
    [model_data["Churn?_True."], model_data.drop(["Churn?_False.", "Churn?_True."], axis=1)], axis=1
)

# %%
train_data, validation_data, test_data = np.split(
    model_data.sample(frac=1, random_state=1729),
    [int(0.7 * len(model_data)), int(0.9 * len(model_data))],
)

# %%
train_data.head()
# Out:
#       Churn?_True.  Account Length  VMail Message   Day Mins  Day Calls  \
# 1697             1              14            300   4.216536          3
# 340              0              97              0   3.122199          5
# 1927             0              17            300   1.460867          5
# 2330             1             144            200  10.026924          4
# 2631             0             199              0   5.127774          2
#
#       Eve Mins  Eve Calls  Night Mins  Night Calls  Intl Mins  Intl Calls  \
# 1697  7.175133          1    0.077795          300   6.140715           5
# 340   3.293510         10    4.663837          150   5.146710           5
# 1927  3.511496          6    4.027071          250   6.525878           5
# 2330  6.811761          1    3.506234          100   4.110792           6
# 2631  1.697019          2    4.530190          150   7.291169           5
#
#       CustServ Calls  State_AK  State_AL  State_AR  State_AZ  State_CA  \
# 1697              10         0         0         0         0         0
# 340                2         0         0         0         0         1
# 1927               5         0         0         1         0         0
# 2330               6         0         0         0         0         0
# 2631               7         0         0         0         0         0
#
#       State_CO  State_CT  State_DC  State_DE  State_FL  State_GA  State_HI  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         1         0         0         0         0         0
#
#       State_IA  State_ID  State_IL  State_IN  State_KS  State_KY  State_LA  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_MA  State_MD  State_ME  State_MI  State_MN  State_MO  State_MS  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         1         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_MT  State_NC  State_ND  State_NE  State_NH  State_NJ  State_NM  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_NV  State_NY  State_OH  State_OK  State_OR  State_PA  State_RI  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_SC  State_SD  State_TN  State_TX  State_UT  State_VA  State_VT  \
# 1697         0         0         0         0         0         0         1
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_WA  State_WI  State_WV  State_WY  Area Code_657  Area Code_658  \
# 1697         0         0         0         0              0              0
# 340          0         0         0         0              0              0
# 1927         0         0         0         0              0              1
# 2330         0         0         0         0              0              0
# 2631         0         0         0         0              0              0
#
#       Area Code_659  Area Code_676  Area Code_677  Area Code_678  \
# 1697              0              0              0              0
# 340               0              1              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              1
#
#       Area Code_686  Area Code_707  Area Code_716  Area Code_727  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_736  Area Code_737  Area Code_758  Area Code_766  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_776  Area Code_777  Area Code_778  Area Code_786  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              1              0              0              0
# 2631              0              0              0              0
#
#       Area Code_787  Area Code_788  Area Code_797  Area Code_798  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_806  Area Code_827  Area Code_836  Area Code_847  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_848  Area Code_858  Area Code_866  Area Code_868  \
# 1697              0              0              0              1
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_876  Area Code_877  Area Code_878  Int'l Plan_no  \
# 1697              0              0              0              1
# 340               0              0              0              0
# 1927              0              0              0              1
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Int'l Plan_yes  VMail Plan_no  VMail Plan_yes
# 1697               0              0               1
# 340                1              1               0
# 1927               0              0               1
# 2330               1              0               1
# 2631               1              1               0

# %%
X_train, y_train = train_data.iloc[:, 1:], train_data.iloc[:, 0]
X_train.shape, y_train.shape
# Out:
# ((3500, 99), (3500,))

# %%
X_train.head()
# Out:
#       Account Length  VMail Message   Day Mins  Day Calls  Eve Mins  \
# 1697              14            300   4.216536          3  7.175133
# 340               97              0   3.122199          5  3.293510
# 1927              17            300   1.460867          5  3.511496
# 2330             144            200  10.026924          4  6.811761
# 2631             199              0   5.127774          2  1.697019
#
#       Eve Calls  Night Mins  Night Calls  Intl Mins  Intl Calls  \
# 1697          1    0.077795          300   6.140715           5
# 340          10    4.663837          150   5.146710           5
# 1927          6    4.027071          250   6.525878           5
# 2330          1    3.506234          100   4.110792           6
# 2631          2    4.530190          150   7.291169           5
#
#       CustServ Calls  State_AK  State_AL  State_AR  State_AZ  State_CA  \
# 1697              10         0         0         0         0         0
# 340                2         0         0         0         0         1
# 1927               5         0         0         1         0         0
# 2330               6         0         0         0         0         0
# 2631               7         0         0         0         0         0
#
#       State_CO  State_CT  State_DC  State_DE  State_FL  State_GA  State_HI  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         1         0         0         0         0         0
#
#       State_IA  State_ID  State_IL  State_IN  State_KS  State_KY  State_LA  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_MA  State_MD  State_ME  State_MI  State_MN  State_MO  State_MS  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         1         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_MT  State_NC  State_ND  State_NE  State_NH  State_NJ  State_NM  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_NV  State_NY  State_OH  State_OK  State_OR  State_PA  State_RI  \
# 1697         0         0         0         0         0         0         0
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_SC  State_SD  State_TN  State_TX  State_UT  State_VA  State_VT  \
# 1697         0         0         0         0         0         0         1
# 340          0         0         0         0         0         0         0
# 1927         0         0         0         0         0         0         0
# 2330         0         0         0         0         0         0         0
# 2631         0         0         0         0         0         0         0
#
#       State_WA  State_WI  State_WV  State_WY  Area Code_657  Area Code_658  \
# 1697         0         0         0         0              0              0
# 340          0         0         0         0              0              0
# 1927         0         0         0         0              0              1
# 2330         0         0         0         0              0              0
# 2631         0         0         0         0              0              0
#
#       Area Code_659  Area Code_676  Area Code_677  Area Code_678  \
# 1697              0              0              0              0
# 340               0              1              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              1
#
#       Area Code_686  Area Code_707  Area Code_716  Area Code_727  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_736  Area Code_737  Area Code_758  Area Code_766  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_776  Area Code_777  Area Code_778  Area Code_786  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              1              0              0              0
# 2631              0              0              0              0
#
#       Area Code_787  Area Code_788  Area Code_797  Area Code_798  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_806  Area Code_827  Area Code_836  Area Code_847  \
# 1697              0              0              0              0
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_848  Area Code_858  Area Code_866  Area Code_868  \
# 1697              0              0              0              1
# 340               0              0              0              0
# 1927              0              0              0              0
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Area Code_876  Area Code_877  Area Code_878  Int'l Plan_no  \
# 1697              0              0              0              1
# 340               0              0              0              0
# 1927              0              0              0              1
# 2330              0              0              0              0
# 2631              0              0              0              0
#
#       Int'l Plan_yes  VMail Plan_no  VMail Plan_yes
# 1697               0              0               1
# 340                1              1               0
# 1927               0              0               1
# 2330               1              0               1
# 2631               1              1               0

# %%
clf = RandomForestClassifier(
    max_depth=5,
    random_state=0
)

# %%
clf.fit(X_train, y_train)

# %%
joblib.dump(clf, "sklearn_model.joblib")

# %% [markdown]
# Test the model loading it:

# %%
clf2 = joblib.load("sklearn_model.joblib")

# %%
clf2.predict_proba(test_data.iloc[0, 1:].values.reshape(1, -1))[0][0]

# %% [markdown]
# ## Test docker before pushing

# %%
import requests
import time

test_dataset = "test.csv"
endpoint = "http://0.0.0.0:8080"
requests.get(f"{endpoint}/ping")

# %%
test_dataset_size = 0  # record the number of rows in data we're sending for inference
count = 0
with open(test_dataset, "r") as f:
    for row in f:
        if test_dataset_size < 120:
            payload = row.rstrip("\n")
            response = requests.post(f"{endpoint}/invocations", payload[2:])
            print(response.json())
            print("", end="", flush=True)
            
            time.sleep(0.5)
        test_dataset_size += 1

print()
print("Done!")
